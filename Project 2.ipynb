# %%
import pandas as pd
import pandasql as ps
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:\\Users\\Dell\\Downloads\\Book_Superstore.xlsx")

# %%
df
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9794    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9795    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9796    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.shape
# Out:
# (9799, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9799 entries, 0 to 9798
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9799 non-null   int64
#  1   Order_ID       9799 non-null   object
#  2   Order_Date     9799 non-null   datetime64[ns]
#  3   Ship_Date      9799 non-null   datetime64[ns]
#  4   Ship_Mode      9799 non-null   object
#  5   Customer_ID    9799 non-null   object
#  6   Customer_Name  9799 non-null   object
#  7   Segment        9799 non-null   object
#  8   Country        9799 non-null   object
#  9   City           9799 non-null   object
#  10  State          9799 non-null   object
#  11  Postal_Code    9788 non-null   float64
#  12  Region         9799 non-null   object
#  13  Product_ID     9799 non-null   object
#  14  Category       9799 non-null   object
#  15  Sub_Category   9799 non-null   object
#  16  Product_Name   9799 non-null   object
# ...

# %%
#Resi PÃ¶lking, Barry FranzÃ¶sisch, Anna HÃ¤berlin, Roy FranzÃ¶sisch, Peter BÃ¼hler, Anna HÃ¤berlin, Jason Fortune-,Resi PÃ¶lking
#Neil FranzÃ¶sisch
for i in df.columns:
    df[i].replace({'Neil FranzÃ¶sisch':'Neil Franzosisch','Resi PÃ¶lking':'Resi Porking','Barry FranzÃ¶sisch':'Barry Franzosisch','Anna HÃ¤berlin':'Anna Haberlin','Roy FranzÃ¶sisch':'Roy Franzosisch','Peter BÃ¼hler':'Peter Buhler','Jason Fortune-':'Jason Fortune'},inplace=True)
    df[i] = df[i]

# %%
df.shape
# Out:
# (9799, 18)

# %%
df2.shape
# Out:
# (9686, 18)

# %%
from datetime import datetime

# %%
df2['Order_Date'] = pd.to_datetime(df2['Order_Date'], errors='coerce')
df2['Ship_Date'] = pd.to_datetime(df2['Ship_Date'], errors='coerce')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11328\3131400204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Order_Date'] = pd.to_datetime(df2['Order_Date'], errors='coerce')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11328\3131400204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Ship_Date'] = pd.to_datetime(df2['Ship_Date'], errors='coerce')

# %%
df2['New'] = df2.apply(lambda x: x['Order_Date'] if x['Order_Date'] <= x['Ship_Date'] else np.NaN, axis=1)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11328\1301552324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['New'] = df2.apply(lambda x: x['Order_Date'] if x['Order_Date'] <= x['Ship_Date'] else np.NaN, axis=1)

# %%
df2.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data = df2.drop(['New'], axis=1)
data
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9794    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9795    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9796    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
data['Order_Date'] = pd.to_datetime(data['Order_Date']).dt.date

# %%
data['Ship_Date'] = pd.to_datetime(data['Ship_Date']).dt.date

# %%
data.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688  2017-06-12  2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.to_excel("C:\\Users\\dell\\Downloads\\superstore_upated.xlsx")
